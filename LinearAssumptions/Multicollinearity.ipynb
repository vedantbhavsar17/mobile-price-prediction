# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
df = pd.read_csv(r"C:\Users\bhavs\OneDrive\Desktop\AdvanceScraping\modiledatasetnew.csv").drop(['brand','processor_brand','os'],axis=1)

# %% [markdown]
# ### The Numarecial columns Where not Hightly Corelated if (LB = -0.8, UB = 0.8)

# %%
plt.figure(figsize=(12,15))
sns.heatmap(df.corr(),annot=True)
# Out:
# <Axes: >

# %% [markdown]
# ### Varience Inflation Factore (VIF)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

vif = []

for i in range(len(df.columns)):
    vif.append(variance_inflation_factor(df.iloc[:,0:],i))

pd.DataFrame({'vif':vif}, index=df.columns).T
# Out:
#        price     reting     is_5g   is_nfc  is_ir_blaster        core  \
# vif  7.75836  26.952925  14.95558  2.97595       2.032871  419.802604
#
#      proccessor_speed        ram  internal_memory  battery_size  fast_charge  \
# vif         59.956068  25.813711         7.559911     86.332041   201.288047
#
#      charging_speed   rear_mp  front_mp  display_size  refresh_rate
# vif        9.198642  5.998999  5.260796    615.216208     57.729314

# %% [markdown]
# - VIF is showing that some of columns have hight multicolinearity

# %% [markdown]
# note: In this project the `prediction` is target, and the multicolinearity only effect on intusion, it just performed for practices perpose
